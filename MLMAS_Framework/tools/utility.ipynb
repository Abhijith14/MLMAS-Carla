# %% [markdown]
# # The Utility code
# ## This code helps in analysing the scenarios record and display the required results.

# %% [markdown]
# ### CARLA Location and Connection information
# >#### Note: The Jupyter notebook should be run from the mlmas environment.
# >#### Make sure that the CARLA simulator is running.

# %%
# Specify the carla location and IP to connect with.
import os

prj_dir = os.getcwd().replace('/MLMAS_Framework/tools','')

CARLA_PATH = prj_dir+'/CARLA_0.9.10.1'


HOST = '127.0.0.1'
PORT = 2000

# %% [markdown]
# ### Import the required libraries

# %%
# run this code and make sure CARLA simulator is running

import glob

import sys
import pandas as pd
import json

try:
    sys.path.append(glob.glob(CARLA_PATH+'/PythonAPI/carla/dist/carla-0.9.10-py3.7-linux-x86_64.egg')[0])
except IndexError:
    print("error >>>")

import carla

# %% [markdown]
# ## 1. Configuration
# ### Record file path to analyse

# %%
recorder_filename = prj_dir+'/results/records/tfus/RouteScenario_8_rep0.log'
recorder_filename2 = prj_dir+'/results/records/MLMAS_tfus/RouteScenario_8_rep0.log'

# %% [markdown]
# ## 2. Analysing the Record Logs
#
# ### - List of the possible blocked agents cases in this scenario:

# %%
TIME = 30
DISTANCE = 10
try:

    client = carla.Client(HOST, PORT)
    client.set_timeout(60.0)

    print(client.show_recorder_actors_blocked(recorder_filename, TIME, DISTANCE))

finally:
    pass
# Out:
# Version: 1
# Map: Town06
# Date: 10/28/22 14:06:56
#
#     Time     Id Actor                                 Duration
#        0    193 walker.pedestrian.0007                     805
#        0    188 walker.pedestrian.0010                     805
#        0    186 walker.pedestrian.0007                     805
#      588    242 vehicle.carlamotors.carlacola              217
#      592    197 vehicle.diamondback.century                213
#      626    182 vehicle.lincoln.mkz2017                    179
#      633    227 vehicle.lincoln.mkz2017                    103
#      635    320 vehicle.lincoln.mkz2017                    102
#      626    303 vehicle.audi.a2                            100
#      690    317 vehicle.audi.etron                          90
#      665    309 vehicle.diamondback.century                 90
#      626    316 vehicle.tesla.model3                        90
#      598    305 vehicle.gazelle.omafiets                    90
#      691    294 vehicle.jeep.wrangler_rubicon               90
#      703    298 vehicle.audi.etron                          80
#      704    343 vehicle.chevrolet.impala                    78
#      729    209 vehicle.volkswagen.t2                       76
#      685    200 vehicle.nissan.patrol                       74
#      718    328 vehicle.diamondback.century                 66
#      740    320 vehicle.lincoln.mkz2017                     66
#      740    279 vehicle.mercedes-benz.coupe                 65
#      741    327 vehicle.dodge_charger.police                64
#      742    280 vehicle.carlamotors.carlacola               63
#      742    322 vehicle.nissan.patrol                       63
#      675    327 vehicle.dodge_charger.police                62
#      743    223 vehicle.lincoln.mkz2017                     62
#      677    280 vehicle.carlamotors.carlacola               61
#      749    238 vehicle.tesla.model3                        56
#      252    182 vehicle.lincoln.mkz2017                     56
#      254    288 vehicle.mercedes-benz.coupe                 55
#      752    282 vehicle.harley-davidson.low_rider           53
#      635    317 vehicle.audi.etron                          53
#      637    294 vehicle.jeep.wrangler_rubicon               52
#      736    306 vehicle.mini.cooperst                       48
#       19    182 vehicle.lincoln.mkz2017                     48
#      692    238 vehicle.tesla.model3                        47
#      711    267 vehicle.toyota.prius                        45
#      761    267 vehicle.toyota.prius                        45
#      761    200 vehicle.nissan.patrol                       44
#      716    286 vehicle.jeep.wrangler_rubicon               44
#      762    286 vehicle.jeep.wrangler_rubicon               43
#      746    339 vehicle.kawasaki.ninja                      40
#      689    225 vehicle.toyota.prius                        36
#        9    319 vehicle.diamondback.century                 36
#      389    343 vehicle.chevrolet.impala                    35
#      689    198 vehicle.nissan.patrol                       35
#      568    343 vehicle.chevrolet.impala                    35
#      296    308 vehicle.nissan.patrol                       35
#      643    311 vehicle.gazelle.omafiets                    35
#      691    312 vehicle.audi.tt                             35
#      236    230 vehicle.nissan.micra                        35
#      236    211 vehicle.mini.cooperst                       35
#      390    322 vehicle.nissan.patrol                       35
#      689    250 vehicle.audi.a2                             35
#      568    207 vehicle.kawasaki.ninja                      35
#      145    337 vehicle.mini.cooperst                       35
#      388    327 vehicle.dodge_charger.police                35
#      553    319 vehicle.diamondback.century                 35
#      251    212 vehicle.audi.etron                          35
#      342    225 vehicle.toyota.prius                        35
#      690    336 vehicle.nissan.patrol                       35
#      147    292 vehicle.chevrolet.impala                    35
#      432    322 vehicle.nissan.patrol                       35
#      538    197 vehicle.diamondback.century                 35
#      146    307 vehicle.chevrolet.impala                    35
#      373    323 vehicle.toyota.prius                        35
#      374    239 vehicle.chevrolet.impala                    35
#      147    238 vehicle.tesla.model3                        35
#      691    253 vehicle.bmw.isetta                          35
#      146    236 vehicle.volkswagen.t2                       35
#      191    335 vehicle.volkswagen.t2                       35
#      387    342 vehicle.diamondback.century                 35
#      100    212 vehicle.audi.etron                          35
#      146    303 vehicle.audi.a2                             35
#      148    334 vehicle.seat.leon                           35
#      599    238 vehicle.tesla.model3                        35
#      100    293 vehicle.jeep.wrangler_rubicon               35
#      433    254 vehicle.audi.tt                             35
#      599    204 vehicle.kawasaki.ninja                      35
#      646    228 vehicle.audi.tt                             35
#      145    269 vehicle.tesla.model3                        35
#      372    258 vehicle.audi.tt                             35
#      644    330 vehicle.yamaha.yzf                          35
#      100    259 vehicle.kawasaki.ninja                      35
#      372    245 vehicle.yamaha.yzf                          35
#      554    216 vehicle.audi.tt                             35
#      508    328 vehicle.diamondback.century                 34
#      599    271 vehicle.toyota.prius                        34
#      418    244 vehicle.carlamotors.carlacola               34
#      554    307 vehicle.chevrolet.impala                    34
#      237    328 vehicle.diamondback.century                 34
#      554    288 vehicle.mercedes-benz.coupe                 34
#      614    263 vehicle.bmw.isetta                          34
#      101    222 vehicle.bmw.isetta                          34
#      327    272 vehicle.dodge_charger.police                34
#      329    341 vehicle.citroen.c3                          34
#      343    317 vehicle.audi.etron                          34
#      192    210 vehicle.nissan.micra                        34
#      343    226 vehicle.mustang.mustang                     34
#      539    242 vehicle.carlamotors.carlacola               34
#      328    223 vehicle.lincoln.mkz2017                     34
#      101    286 vehicle.jeep.wrangler_rubicon               34
#      193    318 vehicle.tesla.model3                        34
#      239    265 vehicle.mustang.mustang                     34
#      328    213 vehicle.tesla.model3                        34
#      556    237 vehicle.audi.etron                          34
#      330    222 vehicle.bmw.isetta                          34
#      238    240 vehicle.yamaha.yzf                          34
#      101    264 vehicle.mercedes-benz.coupe                 34
#      192    209 vehicle.volkswagen.t2                       34
#      196    324 vehicle.mini.cooperst                       34
#      388    267 vehicle.toyota.prius                        34
#      645    299 vehicle.seat.leon                           34
#      196    306 vehicle.mini.cooperst                       34
#      192    317 vehicle.audi.etron                          34
#      238    283 vehicle.audi.a2                             34
#      240    320 vehicle.lincoln.mkz2017                     34
#      283    295 vehicle.citroen.c3                          34
#      630    327 vehicle.dodge_charger.police                34
#      736    240 vehicle.yamaha.yzf                          34
#      195    298 vehicle.audi.etron                          34
#      283    301 vehicle.mercedes-benz.coupe                 34
#      299    242 vehicle.carlamotors.carlacola               34
#      328    235 vehicle.volkswagen.t2                       34
#      328    228 vehicle.audi.tt                             34
#      464    296 vehicle.mercedes-benz.coupe                 34
#      298    333 vehicle.mercedes-benz.coupe                 33
#      509    243 vehicle.lincoln.mkz2017                     33
#      237    253 vehicle.bmw.isetta                          33
#      374    311 vehicle.gazelle.omafiets                    33
#      558    280 vehicle.carlamotors.carlacola               33
#      419    229 vehicle.bmw.isetta                          33
#      192    329 vehicle.mercedes-benz.coupe                 33
#      420    259 vehicle.kawasaki.ninja                      33
#      147    278 vehicle.volkswagen.t2                       33
#      420    284 vehicle.volkswagen.t2                       33
#      389    240 vehicle.yamaha.yzf                          33
#      419    279 vehicle.mercedes-benz.coupe                 33
#      661    212 vehicle.audi.etron                          33
#      333    215 vehicle.audi.tt                             33
#      691    221 vehicle.gazelle.omafiets                    33
#      298    256 vehicle.tesla.model3                        33
#      464    255 vehicle.bmw.isetta                          33
#      283    321 vehicle.toyota.prius                        33
#      194    225 vehicle.toyota.prius                        33
#      253    338 vehicle.kawasaki.ninja                      33
#      376    215 vehicle.audi.tt                             33
#      570    276 vehicle.mini.cooperst                       33
#      646    301 vehicle.mercedes-benz.coupe                 33
#      194    296 vehicle.mercedes-benz.coupe                 33
#      240    343 vehicle.chevrolet.impala                    33
#      647    284 vehicle.volkswagen.t2                       33
#      148    256 vehicle.tesla.model3                        33
#      420    332 vehicle.tesla.model3                        33
#      466    202 vehicle.tesla.cybertruck                    33
#      241    267 vehicle.toyota.prius                        32
#      737    206 vehicle.dodge_charger.police                32
#      285    216 vehicle.audi.tt                             32
#      332    264 vehicle.mercedes-benz.coupe                 32
#      240    294 vehicle.jeep.wrangler_rubicon               32
#      243    295 vehicle.citroen.c3                          32
#      285    262 vehicle.kawasaki.ninja                      32
#      377    286 vehicle.jeep.wrangler_rubicon               32
#      300    330 vehicle.yamaha.yzf                          32
#      149    332 vehicle.tesla.model3                        32
#      241    261 vehicle.citroen.c3                          32
#      335    286 vehicle.jeep.wrangler_rubicon               32
#      243    322 vehicle.nissan.patrol                       32
#      617    328 vehicle.diamondback.century                 32
#      239    324 vehicle.mini.cooperst                       32
#      378    337 vehicle.mini.cooperst                       32
#      196    198 vehicle.nissan.patrol                       32
#      390    320 vehicle.lincoln.mkz2017                     32
#      194    305 vehicle.gazelle.omafiets                    32
#      285    254 vehicle.audi.tt                             32
#      333    311 vehicle.gazelle.omafiets                    32
#      618    322 vehicle.nissan.patrol                       32
#      332    331 vehicle.mini.cooperst                       32
#      571    325 vehicle.harley-davidson.low_rider           32
#      195    241 vehicle.volkswagen.t2                       32
#      467    265 vehicle.mustang.mustang                     32
#       13    276 vehicle.mini.cooperst                       32
#      196    226 vehicle.mustang.mustang                     32
#      289    341 vehicle.citroen.c3                          32
#      301    303 vehicle.audi.a2                             32
#      242    213 vehicle.tesla.model3                        32
#      288    272 vehicle.dodge_charger.police                31
#      377    314 vehicle.citroen.c3                          31
#      290    222 vehicle.bmw.isetta                          31
#      332    312 vehicle.audi.tt                             31
#      289    223 vehicle.lincoln.mkz2017                     31
#      330    206 vehicle.dodge_charger.police                31
#      334    258 vehicle.audi.tt                             31
#      648    306 vehicle.mini.cooperst                       31
#      331    280 vehicle.carlamotors.carlacola               31
#      334    244 vehicle.carlamotors.carlacola               31
#      241    306 vehicle.mini.cooperst                       31
#      287    247 vehicle.nissan.patrol                       31
#      287    207 vehicle.kawasaki.ninja                      31
#      292    311 vehicle.gazelle.omafiets                    31
#      331    282 vehicle.harley-davidson.low_rider           31
#      337    337 vehicle.mini.cooperst                       31
#      376    252 vehicle.gazelle.omafiets                    31
#      332    290 vehicle.gazelle.omafiets                    31
#      244    340 vehicle.tesla.cybertruck                    31
#      287    325 vehicle.harley-davidson.low_rider           31
#      573    286 vehicle.jeep.wrangler_rubicon               31
#      303    237 vehicle.audi.etron                          31
#      198    202 vehicle.tesla.cybertruck                    30
#      649    224 vehicle.diamondback.century                 30
#      754    233 vehicle.bh.crossbike                        30
#      759    230 vehicle.nissan.micra                        30
#      246    254 vehicle.audi.tt                             30
#      286    233 vehicle.bh.crossbike                        30
#      759    208 vehicle.audi.etron                          30
#      105    201 vehicle.diamondback.century                 30
#      468    205 vehicle.diamondback.century                 30
#      739    201 vehicle.diamondback.century                 30
#      286    205 vehicle.diamondback.century                 30
#      289    243 vehicle.lincoln.mkz2017                     30
#      758    307 vehicle.chevrolet.impala                    30
#
# Frames: 16122
# Duration: 806.05 seconds

# %% [markdown]
# ### - List of all collission cases in this scenario

# %%
try:

    client = carla.Client(HOST, PORT)
    client.set_timeout(60.0)

    print(client.show_recorder_collisions(recorder_filename, "v", "a"))

finally:
    pass
# Out:
# Version: 1
# Map: Town02
# Date: 10/28/22 18:20:11
#
#     Time  Types     Id Actor 1                                 Id Actor 2
#      155   v v     681 vehicle.lincoln.mkz2017                784 vehicle.tesla.model3
#      156   v v     681 vehicle.lincoln.mkz2017                784 vehicle.tesla.model3
#      212   v v     681 vehicle.lincoln.mkz2017                784 vehicle.tesla.model3
#      269   v v     681 vehicle.lincoln.mkz2017                784 vehicle.tesla.model3
#      326   v v     681 vehicle.lincoln.mkz2017                784 vehicle.tesla.model3
#      382   v v     681 vehicle.lincoln.mkz2017                784 vehicle.tesla.model3
#
# Frames: 7985
# Duration: 399 seconds

# %% [markdown]
# ## 3. Run the Scenario in a Specific Period
# ### - Baseed on the above code information specify the following:
# in the replay_file method replay_file(record_filename, start_sec, end_sec, camera_actor_id):
# - start_sec: From which second you want to start the scenario (eg. you want to start 3 sec before the collision happen based on the previous code information)
# - duration: Which second you want the scenario to stop.
# - camera_actor_id: based on the previous code information, you can get the id of the vehicle you want to follow, and specify it in this argument. however, if the id is invalud, the camera will be always shows from top. (By default configured to get the id of the hero-car that controlled by the model)

# %%
## Change the start time and the duration for the scenario to rerun in the specify period.
Start_Time = 154
Duration = 3000
p = "2"
def get_hero_vehicle(client):
    try:
        act_list = client.show_recorder_file_info(recorder_filename, False).splitlines()
        
        for i in range(len(act_list)):
                if "role_name = hero" in act_list[i]:
                    s = act_list[i-5]
                    s = s[7:s.find(':')]
                    return int(s)

    finally:
        pass
try:
    
    client = carla.Client(HOST, PORT)
    client.set_timeout(60.0)
    client.reload_world()
    client.replay_file(recorder_filename,
                       time_start=Start_Time,
                       duration=Duration,
                       follow_id = get_hero_vehicle(client))

finally:
    pass

# %%
## Change the start time and the duration for the scenario to rerun in the specify period.
Start_Time = 230
Duration = 3000
p = "2"
def get_hero_vehicle(client):
    try:
        act_list = client.show_recorder_file_info(recorder_filename2, False).splitlines()
        
        for i in range(len(act_list)):
                if "role_name = hero" in act_list[i]:
                    s = act_list[i-5]
                    s = s[7:s.find(':')]
                    return int(s)

    finally:
        pass
try:
    
    client = carla.Client(HOST, PORT)
    client.set_timeout(60.0)
    client.reload_world()
    client.replay_file(recorder_filename2,
                       time_start=Start_Time,
                       duration=Duration,
                       follow_id = get_hero_vehicle(client))

finally:
    pass

# %% [markdown]
# ### =================== End Of Scenario Runner ===================

# %% [markdown]
# # Results Statistics

# %% [markdown]
# ## 1. configuration
# ### Configure of the results files location

# %%
mlmas_leaderboard_results_file = os.getcwd().replace('/MLMAS_Framework/tools','/results/MLMAS_tfus_results.json')
mlmas_additional_metrics_file = os.getcwd().replace('/MLMAS_Framework/tools','/results/MLMAS_tfus_results_jason_metrics.csv')
lav_leaderboard_results = os.getcwd().replace('/MLMAS_Framework/tools','/results/transfuser_longest6.json')

# %% [markdown]
# ### Load the files

# %%
def loadLeaderboardJson(filepath):
    f = open(os.path.realpath(filepath))
    return json.load(f)
    

def geLeaderboardMetrics(jsn):
    leaderboard_metrics = jsn['values']
    leaderboard_df = pd.DataFrame([jsn['values']],
                                  columns=jsn['labels'])
    leaderboard_df = leaderboard_df.astype(float)
    
    return leaderboard_df



mlmas_leaderboard_jsn = loadLeaderboardJson(mlmas_leaderboard_results_file)
lav_leaderboard_jsn = loadLeaderboardJson(lav_leaderboard_results)

# %% [markdown]
# ## 2. Display the leaderboard results

# %%
mlmas_leaderboard_df = geLeaderboardMetrics(mlmas_leaderboard_jsn)
lav_leaderboard_df = geLeaderboardMetrics(lav_leaderboard_jsn)
display(mlmas_leaderboard_df)
print("== MLMAS Framework with LAV Model Leaderboard Metrics results ==")
print("== ========================================================== ==")
display(lav_leaderboard_df)
print("== LAV Model Only Leaderboard Metrics results ==")

# %%
def mergeTwoLeaderbordMetricsResults(title1, title2, df1, df2):
    score_columns = df1.columns.values[0:3]
    df_s1 = df1[score_columns]
    df_s1.loc[:,2:3] = df_s1[score_columns[2]].values*100
    df_s2 = df2[score_columns]
    df_s2.loc[:,2:3] = df_s2[score_columns[2]].values*100
    
    collisions_columns = df1.columns.values[3:6]
    
    road_columns = df1.columns.values[6:9]
    
    other_columns = df1.columns.values[9:]
    
    final_df_s = pd.DataFrame({title1: df_s1.values[0]
                  , title2: df_s2.values[0]
                  , 'Results_Higher_is_Better': score_columns}) 
    
    final_df_c = pd.DataFrame({title1: df1[collisions_columns].values[0]
          , title2: df2[collisions_columns].values[0]
          , 'Results_Lower_is_Better': collisions_columns}) 
    
    final_df_r = pd.DataFrame({title1: df1[road_columns].values[0]
              , title2: df2[road_columns].values[0]
              , 'Results_Lower_is_Better': road_columns}) 
    
    final_df_o = pd.DataFrame({title1: df1[other_columns].values[0]
          , title2: df2[other_columns].values[0]
          , 'Results_Lower_is_Better': other_columns}) 
        
        
    final_df_s.index = final_df_s.Results_Higher_is_Better
    final_df_c.index = final_df_c.Results_Lower_is_Better
    final_df_o.index = final_df_o.Results_Lower_is_Better
    final_df_r.index = final_df_r.Results_Lower_is_Better
    return final_df_s, final_df_c, final_df_o, final_df_r

def show_values(g, pr="%", is_vertical = True):
    for p in g.patches:
        width = p.get_width()
        height = p.get_height()
        x, y = p.get_xy() 
        if is_vertical:
            g.annotate(f'{round(height,1)}{pr}' if pr == "%" else f'{height}{pr}', (x + width/2, y + height*1.02), ha='center')
        else:
            g.annotate(f'{width}{pr}', (x + width + 0.09, y + height/2), ha='center')

# %%
import matplotlib.pyplot as plt
font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 17}

plt.rc('font', **font)


final_df_s, final_df_c, final_df_o, final_df_r = mergeTwoLeaderbordMetricsResults('transfuser','ML-MAS', lav_leaderboard_df ,mlmas_leaderboard_df)
graph = final_df_s.plot.bar(figsize=(13,8))

graph2 = final_df_c.plot.bar(figsize=(13,8))
graph3 = final_df_r.plot.bar(figsize=(13,8))
graph4 = final_df_o.plot.bar(figsize=(11,9))

plt.tight_layout()
show_values(graph)
show_values(graph2, pr="")
show_values(graph3, pr="")
show_values(graph4, pr="")

# %% [markdown]
# ## 3. Jason Agent Additional Metrics

# %%
jason_metrics_csv = pd.read_csv(mlmas_additional_metrics_file, delimiter=';')

final_columns = jason_metrics_csv.columns.values
final_columns[6], final_columns[7] = final_columns[7], final_columns[6]

jason_metrics_csv = jason_metrics_csv[final_columns]
additional_metrics_columns = ["Total Frames", 
                              "Front \nCollision Avoidance",
                             "Far Crossing \nCollision Avoidance",
                             "Close Crossing \nCollision Avoidance",
                             "Back \nCollision Avoidance",
                             "Traffic Light \nGreen [Go]",
                             "Traffic Light \nSlowdown",
                             "Traffic jam \ninterference"]
jason_metrics_csv.columns = additional_metrics_columns

print("== The additional Jason Agent metrics in each scenario")
jason_metrics_csv

# %% [markdown]
# ## Summary of the additional metrics

# %%
jason_metrics_csv.describe()

# %%
font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 17}

plt.rc('font', **font)

mean_percentage = round(jason_metrics_csv.describe()*100,1)
mean_percentage = mean_percentage[additional_metrics_columns[1:]][1:2].values[0]
final_df_s = pd.DataFrame({'Interference_Percentage': mean_percentage
                  , 'Interference_Type': additional_metrics_columns[1:]}) 

final_df_s.index = final_df_s.Interference_Type
final_df_s = final_df_s.sort_values(by=["Interference_Percentage"])
graph = final_df_s.plot.barh(figsize=(13,13))
graph.set_title("Average Jason Agent Interference Percentage of the Whole Evaluation Time")
show_values(graph, is_vertical= False)

print("Total Average Agent Interferance Percentage: (%.1f%s)"%(mean_percentage.sum(),"%"))

# %%
total_df = pd.DataFrame({"Models":["ML-Model","(BDI) Agent"], "Contribution": [100 - mean_percentage.sum(), mean_percentage.sum()]})
total_df.index = total_df.Models

plot = total_df.plot.pie(y='Contribution', title="The ML-Model vs (BDI) Agent Contribution", legend=False, \
                   autopct='%1.1f%%', explode=(0, 0.1), \
                   shadow=True, 
                         startangle=-4,figsize=(8, 8))
